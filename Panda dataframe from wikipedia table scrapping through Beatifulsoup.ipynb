# %%
from lxml import html
import requests

# %%
page = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
tree=html.fromstring(page.content)

# %%
from bs4 import BeautifulSoup

# %%
page.content

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
soup

# %%
print(soup.prettify())

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})

# %%
My_table

# %%
links=My_table.findAll('a')

# %%
links

# %%
Neighborhood = []
for link in links:
    Neighborhood.append(link.get('title'))

# %%
Neighborhood

# %%
import pandas as pd
df=pd.DataFrame()
df['Neighborhood']=Neighborhood

df
# Out:
#                   Neighborhood
# 0                   North York
# 1                    Parkwoods
# 2                   North York
# 3             Victoria Village
# 4             Downtown Toronto
# 5       Harbourfront (Toronto)
# 6             Downtown Toronto
# 7                  Regent Park
# 8                   North York
# 9             Lawrence Heights
# 10                  North York
# 11              Lawrence Manor
# 12      Queen's Park (Toronto)
# 13                   Etobicoke
# 14            Islington Avenue
# 15        Scarborough, Toronto
# 16              Rouge, Toronto
# 17        Scarborough, Toronto
# 18            Malvern, Toronto
# 19                  North York
# 20                   East York
# 21            Woodbine Gardens
# 22                   East York
# 23               Parkview Hill
# 24            Downtown Toronto
# 25                     Ryerson
# 26            Downtown Toronto
# 27                  North York
# 28          Glencairn, Ontario
# ...

# %%
for string in soup.stripped_strings:
    print(repr(string))

# %% [markdown]
# From here, it is pretty simple to look at the firsts values of the table containing the postal codes, Borough and Neighborhood, til the last, and copy them, insert it into Excel file, and finally reading it back in python via panda dataframe. It Excel its pretty straight forward to take the '' away from the values, just for the sake of presentation, and probably less inconvenients while manipulating the data correctly.

# %%
df=pd.read_excel('C:/Users/YO/Desktop/Capstone.xlsx')

# %%
df
# Out:
#                  Neighborhood
# 0                         M1A
# 1                Not assigned
# 2                Not assigned
# 3                         M2A
# 4                Not assigned
# 5                Not assigned
# 6                         M3A
# 7                  North York
# 8                   Parkwoods
# 9                         M4A
# 10                 North York
# 11           Victoria Village
# 12                        M5A
# 13           Downtown Toronto
# 14               Harbourfront
# 15                        M5A
# 16           Downtown Toronto
# 17                Regent Park
# 18                        M6A
# 19                 North York
# 20           Lawrence Heights
# 21                        M6A
# 22                 North York
# 23             Lawrence Manor
# 24                        M7A
# 25                     s Park
# 26               Not assigned
# 27                        M8A
# 28               Not assigned
# 29               Not assigned
# ...

# %%
PostalCode=df.iloc[0::3, :]

# %%
Borough=df.iloc[1::3, :]

# %%
Neighborhood=df.iloc[2::3, :]

# %%
N=Neighborhood.reset_index()

# %%
B=Borough.reset_index()

# %%
P=PostalCode.reset_index()

# %%
N.drop(columns='index', inplace=True)

# %%
B.drop(columns='index', inplace=True)

# %%
P.drop(columns='index', inplace=True)

# %%
N1=N.copy()

# %%
N1['Borough']=B

# %%
N1['Postal Code']=P

# %%
N1
# Out:
#                                           Neighborhood           Borough  \
# 0                                         Not assigned      Not assigned
# 1                                         Not assigned      Not assigned
# 2                                            Parkwoods        North York
# 3                                     Victoria Village        North York
# 4                                         Harbourfront  Downtown Toronto
# 5                                          Regent Park  Downtown Toronto
# 6                                     Lawrence Heights        North York
# 7                                       Lawrence Manor        North York
# 8                                         Not assigned            s Park
# 9                                         Not assigned      Not assigned
# 10                                    Islington Avenue         Etobicoke
# 11                                               Rouge       Scarborough
# ...

# %%
N2=N1[['Postal Code', 'Neighborhood', 'Borough']]

# %%
N2
# Out:
#     Postal Code                                       Neighborhood  \
# 0           M1A                                       Not assigned
# 1           M2A                                       Not assigned
# 2           M3A                                          Parkwoods
# 3           M4A                                   Victoria Village
# 4           M5A                                       Harbourfront
# 5           M5A                                        Regent Park
# 6           M6A                                   Lawrence Heights
# 7           M6A                                     Lawrence Manor
# 8           M7A                                       Not assigned
# 9           M8A                                       Not assigned
# 10          M9A                                   Islington Avenue
# 11          M1B                                              Rouge
# 12          M1B                                            Malvern
# ...

# %%
N3=N2[N2.Neighborhood != "Not assigned"]

# %%
N3
# Out:
#     Postal Code                                       Neighborhood  \
# 2           M3A                                          Parkwoods
# 3           M4A                                   Victoria Village
# 4           M5A                                       Harbourfront
# 5           M5A                                        Regent Park
# 6           M6A                                   Lawrence Heights
# 7           M6A                                     Lawrence Manor
# 10          M9A                                   Islington Avenue
# 11          M1B                                              Rouge
# 12          M1B                                            Malvern
# 14          M3B                                    Don Mills North
# 15          M4B                                   Woodbine Gardens
# 16          M4B                                      Parkview Hill
# 17          M5B                                            Ryerson
# ...

# %%
N4=N3.reset_index()

# %%
N5=N4.drop(columns=['index'])

# %%
N5
# Out:
#     Postal Code                                       Neighborhood  \
# 0           M3A                                          Parkwoods
# 1           M4A                                   Victoria Village
# 2           M5A                                       Harbourfront
# 3           M5A                                        Regent Park
# 4           M6A                                   Lawrence Heights
# 5           M6A                                     Lawrence Manor
# 6           M9A                                   Islington Avenue
# 7           M1B                                              Rouge
# 8           M1B                                            Malvern
# 9           M3B                                    Don Mills North
# 10          M4B                                   Woodbine Gardens
# 11          M4B                                      Parkview Hill
# 12          M5B                                            Ryerson
# ...

# %% [markdown]
# Try to group them in order to obrain a single Postal Code for each Borough

# %%
def f(x):
     return pd.Series(dict(Borough = ", ".join(x['Borough']), 
                        Neighborhood = "%s" % ', '.join(x['Neighborhood'])))

# %%
N9=N5.groupby('Postal Code').apply(f)

# %%
N9
# Out:
#                                                        Borough  \
# Postal Code
# M1B                                   Scarborough, Scarborough
# M1C                      Scarborough, Scarborough, Scarborough
# M1E                      Scarborough, Scarborough, Scarborough
# M1G                                                Scarborough
# M1H                                                Scarborough
# M1J                                                Scarborough
# M1K                      Scarborough, Scarborough, Scarborough
# M1L                      Scarborough, Scarborough, Scarborough
# M1M                      Scarborough, Scarborough, Scarborough
# M1N                                   Scarborough, Scarborough
# M1P                      Scarborough, Scarborough, Scarborough
# M1R                                   Scarborough, Scarborough
# M1S                                                Scarborough
# M1T                      Scarborough, Scarborough, Scarborough
# ...

# %% [markdown]
# The remain problem is that the Borough is duplicated or triplicated acording to how many times the same Postal Code its repeated, havent yet solved the issue, probably slicing the column, exporting it to Excel, manipulate it there and finally reading it back with panda and insert it while removing the old Borough column may solve it, i try to find different ways in python, as unique, but it seems that panda doesnt recognize that it is a duplicated register. So i leave it here, cause of time pressure.

# %%
N9.to_excel('archivo1.xlsx', index=True)

# %%
N11=pd.read_excel('C:/Users/YO/Desktop/archivo1.xlsx')

# %%
N11
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...
